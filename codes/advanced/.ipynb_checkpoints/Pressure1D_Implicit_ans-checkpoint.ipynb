# %% [markdown]
# ### Jupyter Labの使い方Tips
# #### **esc +**
# esc + MでMarkdown，esc + Yでコード，esc + A/Bで現在のセルの上/下にセルを追加，esc + Xでセルをカット
# #### **その他**
# JupyterLabのメニュー「View」→「Show Line Numbers」にチェックを入れると、行番号が表示
#
# Edit > Clear all outputで全てのセルの出力をクリア

# %% [markdown]
# <center>
#     <h1 style="color:blue"><b>1次元圧力拡散方程式</b></h1>
# </center>
# ここでは陰解法による1次元圧力拡散方程式を解くプログラム作成を目指す。離散化手法は陰解法を採用し，離散化式の単位を流量とする。

# %% [markdown]
# <h2><b><u>支配方程式</u></b></h2>
# 密度が一定の，1次元で水平方向に広がる帯水層の質量保存則は
# <br><br>
# $$
# \rho \phi\left(
# \frac{1}{\rho}\frac{\partial \rho}{\partial P}+\frac{1}{\phi}\frac{\partial \phi}{\partial P}
# \right)
# \frac{\partial P}{\partial t}
# = \rho\frac{\partial}{\partial x}\frac{k}{\mu}\frac{\partial P}{\partial x}+\frac{\tilde{m}}{V}\tag{1}
# $$
# <br><br>
# となる。$\tfrac{1}{\rho}\frac{\partial \rho}{\partial P}+\frac{1}{\phi}\frac{\partial \phi}{\partial P}=c$（圧縮係数）とおき，両辺を密度$\rho$で除算すると，
# <br><br>
# $$
# \phi c \frac{\partial P}{\partial t}
# = \frac{\partial}{\partial x}\frac{k}{\mu}\frac{\partial P}{\partial x}+\frac{Q}{V}\tag{2}
# $$
# <br><br>
# 以下式(2)を離散化して解く

# %% [markdown]
# <h2><b><u>問題設定</u></b></h2>
# 1次元の圧力拡散方程式を解くが，下図のように断面積Aを持つ直方体状の帯水層を想定する。
# <center>
# <img src="fig/Aquifer.png" width = "600px"></img>
# </center>

# %% [markdown]
# <h2><b><u>離散化</u></b></h2>
# $i$ 番目のグリッドにおける離散化式を導出する。グリッドの体積 $V$ を両辺にかけて
# <br><br>
# $$
# V\phi c \frac{\partial P}{\partial t}
# = V\frac{\partial}{\partial x}\frac{k}{\mu}\frac{\partial P}{\partial x}+Q\tag{3}
# $$
# <br><br>
# を得る。ただし，$Q$ はソース/シンク項で，坑井による注水/揚水に相当する。
# <a href = "https://te288.github.io/intro_to_NA2022/textbook/04_intro2ReservoirSim.pdf">貯留層解析</a>で説明した通り，陰解法の場合式(3)の両辺は<br><br>
# $$
# V\phi c \frac{\partial P}{\partial t}=\phi c A\Delta x \frac{P^{\left(n+1\right)}_{i}-P^{\left(n\right)}_{i}}{\Delta t}\tag{4}
# $$
# <br>
# $$
# V\frac{\partial}{\partial x}\frac{k}{\mu}\frac{\partial P}{\partial x}+Q
# =
# \left.\frac{kA}{\mu\Delta x}\right|_{i+\frac{1}{2}}\left(P^{\left(n+1\right)}_{i+1}-P^{\left(n+1\right)}_{i}\right)
# -
# \left.\frac{kA}{\mu\Delta x}\right|_{i-\frac{1}{2}}\left(P^{\left(n+1\right)}_{i}-P^{\left(n+1\right)}_{i-1}\right)
# +
# Q_i\tag{5}
# $$
# <br><br>
# 式(4)と式(5)をまとめて整理すると
# <br><br>
# $$
# -\left.\frac{kA}{\mu\Delta x}\right|_{i+\frac{1}{2}}P^{\left(n+1\right)}_{i+1}
# +
# \left(\left(\frac{kA}{\mu\Delta x}\right|_{i+\frac{1}{2}}
# +\left.\frac{kA}{\mu\Delta x}\right|_{i-\frac{1}{2}}+\left(\frac{\phi c V }{\Delta t}\right)\right)P^{\left(n+1\right)}_{i}
# -\left.\frac{kA}{\mu\Delta x}\right|_{i-\frac{1}{2}}P^{\left(n+1\right)}_{i-1}
# =
# \frac{\phi c V }{\Delta t}P^{\left(n\right)}_i + Q
# \tag{6}
# $$

# %% [markdown]
# <h3>!確認</h3>
# $0$ と $N-1$ 番目のグリッドについて，不透水/圧力一定 $\left(P=P_b\right)$ 境界の場合の離散化式は？

# %% [markdown]
# <h3>問題</h3>
# 実際のプログラミングでは，
# $$
# \left.\frac{kA}{\mu\Delta x}\right|_{i\pm\frac{1}{2}}
# $$
# の計算で$k_i$と$k_{i\pm1}$の調和平均を計算する必要がある。調和平均の定義は
# $$
# x_H = \dfrac{1}{\frac{1}{n}\left(\frac{1}{x_1}+\frac{1}{x_2}+...+\frac{1}{x_{n-1}}+\frac{1}{x_{n}}\right)}
# $$
# ところが２つのデータ<code>a</code>，<code>b</code>の調和平均<code>2/(1/a+1/b)</code> では<code>a</code>，<code>b</code>のどちらかが<code>0</code>であるとき，Pythonでは

# %%
a = 10; b = 0;
2/(1/a + 1/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 a = 10; b = 0;
# ----> 2 2/(1/a + 1/b)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# のようにエラーとなってしまう。このエラーを発生させない為には，どのようなコードを書けばよいだろうか？

# %% [markdown]
# <h3 style="color:red">解答</h3>
# $$
# x_H = \frac{1}{ \frac{1}{2}\left(\frac{1}{a}+\frac{1}{b}\right) } = \frac{2ab}{a+b}
# $$
# と変形すれば，<code>0</code>除算を回避できる。

# %%
2*(a*b)/(a+b)
# Out:
# 0.0

# %% [markdown]
# <h2><b><u>実装</u></b></h2>

# %%
## Import Modules & Plot function
import numpy as np
from scipy.stats import hmean
from scipy.sparse import spdiags
import matplotlib.pyplot as plt

def SavePlot(x, P, t, L):
  # Function to Plot & Save Pressure
  # fig = plt.figure()
    plt.plot(x, P_new, label='t={0:05.2f}'.format(t)) 
    plt.xlabel('x[m]')
    plt.ylabel('Pressure [Pa]')
    plt.xlim(0, L)
    #plt.ylim(-1, 1)
    plt.grid()
    plt.title('Aquifer Pressure@{0:05.2f}[s]'.format(t))
  # fig.savefig('t={0:05.2f}.png'.format(t)) #画像保存には20行目と21行目も実行
  # plt.clf()

# %%
## Input Parmeters
# time step & boundary condition controll
dt   = 43200   # dt [s] 43200[s] is equal to 0.5 days
tmax = dt*365*100 # Time to stop simlation [s]
nout = 10000  # output result ever nout step[s]
# Variable to decide Boundary condition
#  1> Neumann, 0> Dirichlet
BC_east = 0 # Boundary at right(x = L) 
BC_west  = 0 # Boundary at Left (x = 0)
Pb_east = 0 # Pressure Value at x = L
Pb_west  = 0 # Pressure Value at x = 0

# Aquifer Geometory & coordinate
L   = 3000     # Length of theReservoir [m]
W   = 10          # Width of the Reservoir [m]
h   = 10         # Tickness of the Reservoir [m]
N   = 100         # Number of Control Volume [-]
dx  = L/N         # Length of Control Volume[m]
A   = W*h           # cross-sectional area of reservoir [m^2]
x   = np.zeros(N) # x coordinate[m]
# Coordinate points of CV-center
x[0]= dx/2
for i in range(1, N):
    x[i] = x[i-1] + dx
    
# Aquifer Properties
perm   = 1e-1*np.ones(N)    # Absolute Permiability Field [m^2]
phi    = 0.3*np.ones(N)  # Porosity Field [-]
#P_init = np.abs(np.sin(x))     # Initial Condition of Pressure [Pa]
P_init = 1e6*np.ones(N)

# Fluid Properties
c    = 1     # Compressibility[Pa^-1]
mu   = 1     # Viscosity of Fluid[Pa*s]

# Well Parameters
Q   = np.zeros(N) # Source vector[m^/s]
# Q[3] = 0.05 # > 0, Injection wells
# Q[5] = -0.05 # < 0, Pumping wells

# %%
## definition of Matrix for Linear simultaneous Eq.
T  = np.zeros([N,N]) # transmissibility Matrix
B   = np.zeros([N,N]) # Volume accumulation Matrix

# T
for i in range(0, N):
    if i == 0:
        Tw = 0
        Te = A/(mu*dx)*(2*( perm[i] * perm[i+1] )/( perm[i] + perm[i+1]) )
        T[i,i] = Tw + Te;
        T[i,i+1] = -Te
    elif i == N-1:
        Tw = A/(mu*dx)*(2*( perm[i-1] * perm[i] )/( perm[i-1] + perm[i]) )
        Te = 0
        T[i,i]    = Tw + Te;
        T[i, i-1] = -Tw
    else:
        Tw = A/(mu*dx)*(2*( perm[i-1] * perm[i] )/( perm[i-1] + perm[i]) )
        Te = A/(mu*dx)*(2*( perm[i] * perm[i+1] )/( perm[i] + perm[i+1]) )
        T[i,i] = Tw + Te;
        T[i,i-1] = -Tw
        T[i,i+1] = -Te

# B
for i in range(0, N):
    B[i,i] = A*dx*phi[i]*c
    
# Boundary Condition and Q
if BC_east == 0:
    Q[0] = 2*T[0,0]*Pb_east
    T[0,0] = T[0,0] + T[0,0];
if BC_west == 0:
    Q[N-1] = 2*T[N-1, N-1]*Pb_west
    T[N-1,N-1] = T[N-1,N-1] + T[N-1,N-1]

# %%
## Simulation
P_old  = np.copy(P_init) # Pressure at n-th step
P_new  = np.copy(P_init) # Pressure at n+1-th step
t = 0
n = 0
fig = plt.figure()

# Plot Initial Condition
SavePlot(x, P_new, t, L)
while True:
    # solve Simultaneous equations
    P_new = np.linalg.solve((T + B/dt), (np.dot(B/dt,P_old)+Q)) 
    
    # Update Values, time step and Add plot
    P_old = np.copy(P_new)
    t = t + dt
    n = n + 1
    
    if t >= tmax:
        break
    
    if n%nout == 0:
        print('{0}th Time step {1:05.2f}'.format(n, t))
        SavePlot(x, P_new, t, L)

            
SavePlot(x, P_new, t, L)
# plt.legend()
plt.show()
# Out:
# 100th Time step 4320000.00
# 200th Time step 8640000.00
# 300th Time step 12960000.00
# 400th Time step 17280000.00
# 500th Time step 21600000.00
# 600th Time step 25920000.00
# 700th Time step 30240000.00
# 800th Time step 34560000.00
# 900th Time step 38880000.00
# 1000th Time step 43200000.00
# 1100th Time step 47520000.00
# 1200th Time step 51840000.00
# 1300th Time step 56160000.00
# 1400th Time step 60480000.00
# 1500th Time step 64800000.00
# 1600th Time step 69120000.00
# 1700th Time step 73440000.00
# 1800th Time step 77760000.00
# 1900th Time step 82080000.00
# 2000th Time step 86400000.00
# 2100th Time step 90720000.00
# 2200th Time step 95040000.00
# 2300th Time step 99360000.00
# 2400th Time step 103680000.00
# 2500th Time step 108000000.00
# 2600th Time step 112320000.00
# 2700th Time step 116640000.00
# 2800th Time step 120960000.00
# 2900th Time step 125280000.00
# 3000th Time step 129600000.00
# 3100th Time step 133920000.00
# 3200th Time step 138240000.00
# 3300th Time step 142560000.00
# 3400th Time step 146880000.00
# 3500th Time step 151200000.00
# 3600th Time step 155520000.00
# 3700th Time step 159840000.00
# 3800th Time step 164160000.00
# 3900th Time step 168480000.00
# 4000th Time step 172800000.00
# 4100th Time step 177120000.00
# 4200th Time step 181440000.00
# 4300th Time step 185760000.00
# 4400th Time step 190080000.00
# 4500th Time step 194400000.00
# 4600th Time step 198720000.00
# 4700th Time step 203040000.00
# 4800th Time step 207360000.00
# 4900th Time step 211680000.00
# 5000th Time step 216000000.00
# 5100th Time step 220320000.00
# 5200th Time step 224640000.00
# 5300th Time step 228960000.00
# 5400th Time step 233280000.00
# 5500th Time step 237600000.00
# 5600th Time step 241920000.00
# 5700th Time step 246240000.00
# 5800th Time step 250560000.00
# 5900th Time step 254880000.00
# 6000th Time step 259200000.00
# 6100th Time step 263520000.00
# 6200th Time step 267840000.00
# 6300th Time step 272160000.00
# 6400th Time step 276480000.00
# 6500th Time step 280800000.00
# 6600th Time step 285120000.00
# 6700th Time step 289440000.00
# 6800th Time step 293760000.00
# 6900th Time step 298080000.00
# 7000th Time step 302400000.00
# 7100th Time step 306720000.00
# 7200th Time step 311040000.00
# 7300th Time step 315360000.00
# 7400th Time step 319680000.00
# 7500th Time step 324000000.00
# 7600th Time step 328320000.00
# 7700th Time step 332640000.00
# 7800th Time step 336960000.00
# 7900th Time step 341280000.00
# 8000th Time step 345600000.00
# 8100th Time step 349920000.00
# 8200th Time step 354240000.00
# 8300th Time step 358560000.00
# 8400th Time step 362880000.00
# 8500th Time step 367200000.00
# 8600th Time step 371520000.00
# 8700th Time step 375840000.00
# 8800th Time step 380160000.00
# 8900th Time step 384480000.00
# 9000th Time step 388800000.00
# 9100th Time step 393120000.00
# 9200th Time step 397440000.00
# 9300th Time step 401760000.00
# 9400th Time step 406080000.00
# 9500th Time step 410400000.00
# 9600th Time step 414720000.00
# 9700th Time step 419040000.00
# 9800th Time step 423360000.00
# 9900th Time step 427680000.00
# 10000th Time step 432000000.00
# 10100th Time step 436320000.00
# 10200th Time step 440640000.00
# 10300th Time step 444960000.00
# 10400th Time step 449280000.00
# 10500th Time step 453600000.00
# 10600th Time step 457920000.00
# 10700th Time step 462240000.00
# 10800th Time step 466560000.00
# 10900th Time step 470880000.00
# 11000th Time step 475200000.00
# 11100th Time step 479520000.00
# 11200th Time step 483840000.00
# 11300th Time step 488160000.00
# 11400th Time step 492480000.00
# 11500th Time step 496800000.00
# 11600th Time step 501120000.00
# 11700th Time step 505440000.00
# 11800th Time step 509760000.00
# 11900th Time step 514080000.00
# 12000th Time step 518400000.00
# 12100th Time step 522720000.00
# 12200th Time step 527040000.00
# 12300th Time step 531360000.00
# 12400th Time step 535680000.00
# 12500th Time step 540000000.00
# 12600th Time step 544320000.00
# 12700th Time step 548640000.00
# 12800th Time step 552960000.00
# 12900th Time step 557280000.00
# 13000th Time step 561600000.00
# 13100th Time step 565920000.00
# 13200th Time step 570240000.00
# 13300th Time step 574560000.00
# 13400th Time step 578880000.00
# 13500th Time step 583200000.00
# 13600th Time step 587520000.00
# 13700th Time step 591840000.00
# 13800th Time step 596160000.00
# 13900th Time step 600480000.00
# 14000th Time step 604800000.00
# 14100th Time step 609120000.00
# 14200th Time step 613440000.00
# 14300th Time step 617760000.00
# 14400th Time step 622080000.00
# 14500th Time step 626400000.00
# 14600th Time step 630720000.00
# 14700th Time step 635040000.00
# 14800th Time step 639360000.00
# 14900th Time step 643680000.00
# 15000th Time step 648000000.00
# 15100th Time step 652320000.00
# 15200th Time step 656640000.00
# 15300th Time step 660960000.00
# 15400th Time step 665280000.00
# 15500th Time step 669600000.00
# 15600th Time step 673920000.00
# 15700th Time step 678240000.00
# 15800th Time step 682560000.00
# 15900th Time step 686880000.00
# 16000th Time step 691200000.00
# 16100th Time step 695520000.00
# 16200th Time step 699840000.00
# 16300th Time step 704160000.00
# 16400th Time step 708480000.00
# 16500th Time step 712800000.00
# 16600th Time step 717120000.00
# 16700th Time step 721440000.00
# 16800th Time step 725760000.00
# 16900th Time step 730080000.00
# 17000th Time step 734400000.00
# 17100th Time step 738720000.00
# 17200th Time step 743040000.00
# 17300th Time step 747360000.00
# 17400th Time step 751680000.00
# 17500th Time step 756000000.00
# 17600th Time step 760320000.00
# 17700th Time step 764640000.00
# 17800th Time step 768960000.00
# 17900th Time step 773280000.00
# 18000th Time step 777600000.00
# 18100th Time step 781920000.00
# 18200th Time step 786240000.00
# 18300th Time step 790560000.00
# 18400th Time step 794880000.00
# 18500th Time step 799200000.00
# 18600th Time step 803520000.00
# 18700th Time step 807840000.00
# 18800th Time step 812160000.00
# 18900th Time step 816480000.00
# 19000th Time step 820800000.00
# 19100th Time step 825120000.00
# 19200th Time step 829440000.00
# 19300th Time step 833760000.00
# 19400th Time step 838080000.00
# 19500th Time step 842400000.00
# 19600th Time step 846720000.00
# 19700th Time step 851040000.00
# 19800th Time step 855360000.00
# 19900th Time step 859680000.00
# 20000th Time step 864000000.00
# 20100th Time step 868320000.00
# 20200th Time step 872640000.00
# 20300th Time step 876960000.00
# 20400th Time step 881280000.00
# 20500th Time step 885600000.00
# 20600th Time step 889920000.00
# 20700th Time step 894240000.00
# 20800th Time step 898560000.00
# 20900th Time step 902880000.00
# 21000th Time step 907200000.00
# 21100th Time step 911520000.00
# 21200th Time step 915840000.00
# 21300th Time step 920160000.00
# 21400th Time step 924480000.00
# 21500th Time step 928800000.00
# 21600th Time step 933120000.00
# 21700th Time step 937440000.00
# 21800th Time step 941760000.00
# 21900th Time step 946080000.00
# 22000th Time step 950400000.00
# 22100th Time step 954720000.00
# 22200th Time step 959040000.00
# 22300th Time step 963360000.00
# 22400th Time step 967680000.00
# 22500th Time step 972000000.00
# 22600th Time step 976320000.00
# 22700th Time step 980640000.00
# 22800th Time step 984960000.00
# 22900th Time step 989280000.00
# 23000th Time step 993600000.00
# 23100th Time step 997920000.00
# 23200th Time step 1002240000.00
# 23300th Time step 1006560000.00
# 23400th Time step 1010880000.00
# 23500th Time step 1015200000.00
# 23600th Time step 1019520000.00
# 23700th Time step 1023840000.00
# 23800th Time step 1028160000.00
# 23900th Time step 1032480000.00
# 24000th Time step 1036800000.00
# 24100th Time step 1041120000.00
# 24200th Time step 1045440000.00
# 24300th Time step 1049760000.00
# 24400th Time step 1054080000.00
# 24500th Time step 1058400000.00
# 24600th Time step 1062720000.00
# 24700th Time step 1067040000.00
# 24800th Time step 1071360000.00
# 24900th Time step 1075680000.00
# 25000th Time step 1080000000.00
# 25100th Time step 1084320000.00
# 25200th Time step 1088640000.00
# 25300th Time step 1092960000.00
# 25400th Time step 1097280000.00
# 25500th Time step 1101600000.00
# 25600th Time step 1105920000.00
# 25700th Time step 1110240000.00
# 25800th Time step 1114560000.00
# 25900th Time step 1118880000.00
# 26000th Time step 1123200000.00
# 26100th Time step 1127520000.00
# 26200th Time step 1131840000.00
# 26300th Time step 1136160000.00
# 26400th Time step 1140480000.00
# 26500th Time step 1144800000.00
# 26600th Time step 1149120000.00
# 26700th Time step 1153440000.00
# 26800th Time step 1157760000.00
# 26900th Time step 1162080000.00
# 27000th Time step 1166400000.00
# 27100th Time step 1170720000.00
# 27200th Time step 1175040000.00
# 27300th Time step 1179360000.00
# 27400th Time step 1183680000.00
# 27500th Time step 1188000000.00
# 27600th Time step 1192320000.00
# 27700th Time step 1196640000.00
# 27800th Time step 1200960000.00
# 27900th Time step 1205280000.00
# 28000th Time step 1209600000.00
# 28100th Time step 1213920000.00
# 28200th Time step 1218240000.00
# 28300th Time step 1222560000.00
# 28400th Time step 1226880000.00
# 28500th Time step 1231200000.00
# 28600th Time step 1235520000.00
# 28700th Time step 1239840000.00
# 28800th Time step 1244160000.00
# 28900th Time step 1248480000.00
# 29000th Time step 1252800000.00
# 29100th Time step 1257120000.00
# 29200th Time step 1261440000.00
# 29300th Time step 1265760000.00
# 29400th Time step 1270080000.00
# 29500th Time step 1274400000.00
# 29600th Time step 1278720000.00
# 29700th Time step 1283040000.00
# 29800th Time step 1287360000.00
# 29900th Time step 1291680000.00
# 30000th Time step 1296000000.00
# 30100th Time step 1300320000.00
# 30200th Time step 1304640000.00
# 30300th Time step 1308960000.00
# 30400th Time step 1313280000.00
# 30500th Time step 1317600000.00
# 30600th Time step 1321920000.00
# 30700th Time step 1326240000.00
# 30800th Time step 1330560000.00
# 30900th Time step 1334880000.00
# 31000th Time step 1339200000.00
# 31100th Time step 1343520000.00
# 31200th Time step 1347840000.00
# 31300th Time step 1352160000.00
# 31400th Time step 1356480000.00
# 31500th Time step 1360800000.00
# 31600th Time step 1365120000.00
# 31700th Time step 1369440000.00
# 31800th Time step 1373760000.00
# 31900th Time step 1378080000.00
# 32000th Time step 1382400000.00
# 32100th Time step 1386720000.00
# 32200th Time step 1391040000.00
# 32300th Time step 1395360000.00
# 32400th Time step 1399680000.00
# 32500th Time step 1404000000.00
# 32600th Time step 1408320000.00
# 32700th Time step 1412640000.00
# 32800th Time step 1416960000.00
# 32900th Time step 1421280000.00
# 33000th Time step 1425600000.00
# 33100th Time step 1429920000.00
# 33200th Time step 1434240000.00
# 33300th Time step 1438560000.00
# 33400th Time step 1442880000.00
# 33500th Time step 1447200000.00
# 33600th Time step 1451520000.00
# 33700th Time step 1455840000.00
# 33800th Time step 1460160000.00
# 33900th Time step 1464480000.00
# 34000th Time step 1468800000.00
# 34100th Time step 1473120000.00
# 34200th Time step 1477440000.00
# 34300th Time step 1481760000.00
# 34400th Time step 1486080000.00
# 34500th Time step 1490400000.00
# 34600th Time step 1494720000.00
# 34700th Time step 1499040000.00
# 34800th Time step 1503360000.00
# 34900th Time step 1507680000.00
# 35000th Time step 1512000000.00
# 35100th Time step 1516320000.00
# 35200th Time step 1520640000.00
# 35300th Time step 1524960000.00
# 35400th Time step 1529280000.00
# 35500th Time step 1533600000.00
# 35600th Time step 1537920000.00
# 35700th Time step 1542240000.00
# 35800th Time step 1546560000.00
# 35900th Time step 1550880000.00
# 36000th Time step 1555200000.00
# 36100th Time step 1559520000.00
# 36200th Time step 1563840000.00
# 36300th Time step 1568160000.00
# 36400th Time step 1572480000.00

# %%
plt.imshow([P_new, P_new], extent = [0, L, 0, 100*W])
plt.colorbar()
